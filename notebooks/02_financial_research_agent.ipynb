# %% [markdown]
# # Financial Research Agent
#
# This notebook tests the financial agent with tools. The workflow is:
#
# 1. The model plans which tools to use.
# 2. Python executes those tools.
# 3. The model receives the tool results and writes the final analysis.
#
# The key difference is that `SYSTEM_PROMPT` is used in the final model call, while `TOOL_PLANNING_PROMPT` is used in the planning call.

# %% [markdown]
# ## Dependencies
#
# From the `agents/financial_research_agent` folder, install dependencies with Poetry if they are not installed yet:
#
# ```bash
# python -m poetry install
# ```
#
# You also need Ollama running and the local model available, for example `qwen2.5:3b`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PROJECT_ROOT
# Out:
# WindowsPath('d:/Documentos/Universidad Externado/Seminario - Multiagentes')

# %%
from agents.financial_research_agent.agent import FinancialResearchAgent
from agents.financial_research_agent.prompts import SYSTEM_PROMPT, TOOL_PLANNING_PROMPT

print("SYSTEM_PROMPT:\n")
print(SYSTEM_PROMPT)
print("\n" + "=" * 80 + "\n")
print("TOOL_PLANNING_PROMPT:\n")
print(TOOL_PLANNING_PROMPT)
# Out:
# SYSTEM_PROMPT:
#
# You are a senior financial research analyst working at an investment firm.
#
# Your job is to help analysts answer questions about stocks, ETFs, performance,
# volatility, drawdowns, trends and risk using only the data returned by tools.
#
# Rules:
# 1. Do not invent prices, dates, tickers or metrics.
# 2. Separate factual findings from interpretation.
# 3. Explain risk in plain business language.
# 4. Mention uncertainty and data limitations explicitly.
# 5. Do not provide personalized investment advice.
# 6. Keep recommendations framed as analytical next steps, not buy/sell orders.
# 7. Use markdown with concise sections.
#
# ================================================================================
#
# TOOL_PLANNING_PROMPT:
#
# You are a tool planning assistant for a financial research agent.
#
# Your only job is to decide which tools should be executed to answer the user's
# financial analysis question.
#
# Return only valid JSON. Do not include markdown, explanations or comments.
# The JSON must follow this schema:
#
# {
#   "tools": [
#     {
#       "name": "tool_name",
#       "arguments": {
#         "argument_name": "argument_value"
#       }
#     }
#   ]
# }
#
# Planning rules:
# 1. Use get_stock_data when the user asks for recent market data or price history.
# 2. Use compute_stock_metrics when the user asks about return, volatility, drawdown or risk.
# 3. Use plot_price_history when the user asks for a chart of one ticker.
# 4. Use compare_stocks when the user asks to compare two or more tickers.
# 5. Prefer period="1y" unless the user asks for another period.
# 6. Preserve explicit time windows from the user:
#    - "last 5 days" -> period="5d"
#    - "last month" -> period="1mo"
#    - "last 6 months" -> period="6mo"
#    - "last year" -> period="1y"
#    - "year to date" -> period="ytd"
# 7. Use lowercase yfinance period values such as "5d", "1mo", "6mo", "1y".
# 8. Use valid ticker strings exactly as financial symbols, for example AAPL, MSFT, SPY.

# %% [markdown]
# ## Create the agent
#
# The agent receives a local Ollama model and builds a `ToolRegistry`. The registry contains the executable tools: download data, compute metrics, create charts, and compare assets.

# %%
agent = FinancialResearchAgent(model_name="qwen2.5:3b")
agent.tool_registry.describe_tools()
# Out:
# [{'name': 'get_stock_data',
#   'description': 'Download recent historical OHLCV data from Yahoo Finance. Arguments: ticker (string), period (string, optional).'},
#  {'name': 'compute_stock_metrics',
#   'description': 'Compute return, volatility and drawdown metrics for one stock or ETF. Arguments: ticker (string), period (string, optional).'},
#  {'name': 'plot_price_history',
#   'description': 'Generate a price history chart for one stock or ETF. Arguments: ticker (string), period (string, optional).'},
#  {'name': 'compare_stocks',
#   'description': 'Compare multiple stocks or ETFs over the same period. Arguments: tickers (list of strings), period (string, optional).'}]

# %% [markdown]
# ## Test question
#
# The question mentions multiple tickers and asks to compare performance and risk. This should trigger `compare_stocks` and, depending on the model plan, may also trigger individual metrics.

# %%
user_question = "Compare the performance, volatility, and drawdown of AAPL, MSFT, and SPY over the last year. Generate a comparative chart."
user_question
# Out:
# 'Compare the performance, volatility, and drawdown of AAPL, MSFT, and SPY over the last year. Generate a comparative chart.'

# %% [markdown]
# ## Step 1: tool planning
#
# This cell internally calls Ollama with:
#
# ```python
# messages=[
#     {"role": "system", "content": TOOL_PLANNING_PROMPT},
#     {"role": "user", "content": build_tool_planning_prompt(...)},
# ]
# ```
#
# The result must be valid JSON.

# %%
tool_plan = agent._plan_tools(user_question)
tool_plan
# Out:
# {'tools': [{'name': 'get_stock_data',
#    'arguments': {'ticker': 'AAPL', 'period': '1y'}},
#   {'name': 'get_stock_data', 'arguments': {'ticker': 'MSFT', 'period': '1y'}},
#   {'name': 'get_stock_data', 'arguments': {'ticker': 'SPY', 'period': '1y'}},
#   {'name': 'compare_stocks',
#    'arguments': {'tickers': ['AAPL', 'MSFT', 'SPY'], 'period': '1y'}}]}

# %% [markdown]
# ## Step 2: execute tools
#
# At this point the LLM is no longer deciding. Python executes exactly the tools included in the previous JSON.

# %%
tool_results = agent._execute_tool_plan(tool_plan)
tool_results
# Out:
# {'step_1_get_stock_data': {'ticker': 'AAPL',
#   'period': '1y',
#   'rows': 251,
#   'start_date': '2025-05-30',
#   'end_date': '2026-05-29',
#   'last_close': 312.06,
#   'last_rows': [{('Date', ''): Timestamp('2026-05-22 00:00:00'),
#     ('Close', 'AAPL'): 308.82000732421875,
#     ('High', 'AAPL'): 311.3999938964844,
#     ('Low', 'AAPL'): 305.8399963378906,
#     ('Open', 'AAPL'): 306.1199951171875,
#     ('Volume', 'AAPL'): 43670200},
#    {('Date', ''): Timestamp('2026-05-26 00:00:00'),
#     ('Close', 'AAPL'): 308.3299865722656,
#     ('High', 'AAPL'): 311.82000732421875,
#     ('Low', 'AAPL'): 307.6700134277344,
#     ('Open', 'AAPL'): 309.55999755859375,
#     ('Volume', 'AAPL'): 48000500},
#    {('Date', ''): Timestamp('2026-05-27 00:00:00'),
#     ('Close', 'AAPL'): 310.8500061035156,
#     ('High', 'AAPL'): 313.260009765625,
#     ('Low', 'AAPL'): 308.29998779296875,
#     ('Open', 'AAPL'): 308.3299865722656,
#     ('Volume', 'AAPL'): 50430900},
#    {('Date', ''): Timestamp('2026-05-28 00:00:00'),
#     ('Close', 'AAPL'): 312.510009765625,
#     ('High', 'AAPL'): 312.79998779296875,
#     ('Low', 'AAPL'): 309.57000732421875,
#     ('Open', 'AAPL'): 310.67999267578125,
#     ('Volume', 'AAPL'): 48220400},
#    {('Date', ''): Timestamp('2026-05-29 00:00:00'),
#     ('Close', 'AAPL'): 312.05999755859375,
#     ('High', 'AAPL'): 315.0,
#     ('Low', 'AAPL'): 309.5299987792969,
#     ('Open', 'AAPL'): 311.7799987792969,
#     ('Volume', 'AAPL'): 69982800}]},
#  'step_2_get_stock_data': {'ticker': 'MSFT',
#   'period': '1y',
#   'rows': 251,
#   'start_date': '2025-05-30',
#   'end_date': '2026-05-29',
#   'last_close': 450.24,
#   'last_rows': [{('Date', ''): Timestamp('2026-05-22 00:00:00'),
#     ('Close', 'MSFT'): 418.57000732421875,
#     ('High', 'MSFT'): 424.3999938964844,
#     ('Low', 'MSFT'): 416.3299865722656,
#     ('Open', 'MSFT'): 419.5400085449219,
#     ('Volume', 'MSFT'): 22390300},
#    {('Date', ''): Timestamp('2026-05-26 00:00:00'),
#     ('Close', 'MSFT'): 416.0299987792969,
#     ('High', 'MSFT'): 419.7699890136719,
#     ('Low', 'MSFT'): 413.0199890136719,
#     ('Open', 'MSFT'): 416.42999267578125,
#     ('Volume', 'MSFT'): 30398000},
#    {('Date', ''): Timestamp('2026-05-27 00:00:00'),
#     ('Close', 'MSFT'): 412.6700134277344,
#     ('High', 'MSFT'): 415.94000244140625,
#     ('Low', 'MSFT'): 409.5799865722656,
#     ('Open', 'MSFT'): 411.010009765625,
#     ('Volume', 'MSFT'): 28901500},
#    {('Date', ''): Timestamp('2026-05-28 00:00:00'),
#     ('Close', 'MSFT'): 426.989990234375,
#     ('High', 'MSFT'): 429.489990234375,
#     ('Low', 'MSFT'): 412.6700134277344,
#     ('Open', 'MSFT'): 412.9800109863281,
#     ('Volume', 'MSFT'): 47250500},
#    {('Date', ''): Timestamp('2026-05-29 00:00:00'),
#     ('Close', 'MSFT'): 450.239990234375,
#     ('High', 'MSFT'): 450.3299865722656,
#     ('Low', 'MSFT'): 432.3599853515625,
#     ('Open', 'MSFT'): 432.54998779296875,
#     ('Volume', 'MSFT'): 79522600}]},
#  'step_3_get_stock_data': {'ticker': 'SPY',
#   'period': '1y',
#   'rows': 251,
#   'start_date': '2025-05-30',
#   'end_date': '2026-05-29',
#   'last_close': 756.48,
#   'last_rows': [{('Date', ''): Timestamp('2026-05-22 00:00:00'),
#     ('Close', 'SPY'): 745.6400146484375,
#     ('High', 'SPY'): 748.9400024414062,
#     ('Low', 'SPY'): 744.47998046875,
#     ('Open', 'SPY'): 746.239990234375,
#     ('Volume', 'SPY'): 41762000},
#    {('Date', ''): Timestamp('2026-05-26 00:00:00'),
#     ('Close', 'SPY'): 750.5900268554688,
#     ('High', 'SPY'): 752.1300048828125,
#     ('Low', 'SPY'): 748.3699951171875,
#     ('Open', 'SPY'): 750.010009765625,
#     ('Volume', 'SPY'): 41123600},
#    {('Date', ''): Timestamp('2026-05-27 00:00:00'),
#     ('Close', 'SPY'): 750.4600219726562,
#     ('High', 'SPY'): 751.3800048828125,
#     ('Low', 'SPY'): 748.219970703125,
#     ('Open', 'SPY'): 750.8800048828125,
#     ('Volume', 'SPY'): 42106300},
#    {('Date', ''): Timestamp('2026-05-28 00:00:00'),
#     ('Close', 'SPY'): 754.5999755859375,
#     ('High', 'SPY'): 755.1500244140625,
#     ('Low', 'SPY'): 749.22998046875,
#     ('Open', 'SPY'): 750.25,
#     ('Volume', 'SPY'): 41562600},
#    {('Date', ''): Timestamp('2026-05-29 00:00:00'),
#     ('Close', 'SPY'): 756.47998046875,
#     ('High', 'SPY'): 758.0800170898438,
#     ('Low', 'SPY'): 754.6900024414062,
#     ('Open', 'SPY'): 755.9000244140625,
#     ('Volume', 'SPY'): 54976100}]},
#  'step_4_compare_stocks': {'tickers': ['AAPL', 'MSFT', 'SPY'],
#   'period': '1y',
#   'metrics': [{'ticker': 'AAPL',
#     'last_close': 312.06,
#     'cumulative_return_pct': 55.99,
#     'annualized_volatility_pct': 22.08,
#     'max_drawdown_pct': -13.8},
#    {'ticker': 'MSFT',
#     'last_close': 450.24,
#     'cumulative_return_pct': -1.42,
#     'annualized_volatility_pct': 24.56,
#     'max_drawdown_pct': -33.91},
#    {'ticker': 'SPY',
#     'last_close': 756.48,
#     'cumulative_return_pct': 29.82,
#     'annualized_volatility_pct': 11.86,
#     'max_drawdown_pct': -8.88}],
#   'chart_path': 'D:\\Documentos\\Universidad Externado\\Seminario - Multiagentes\\agents\\financial_research_agent\\outputs\\aapl_msft_spy_1y_comparison.png',
#   'start_date': '2025-05-30',
#   'end_date': '2026-05-29'}}

# %% [markdown]
# ## Step 3: final answer
#
# This is the call where the financial analyst `SYSTEM_PROMPT` is used:
#
# ```python
# messages=[
#     {"role": "system", "content": SYSTEM_PROMPT},
#     {"role": "user", "content": final_prompt},
# ]
# ```
#
# The model does not query Yahoo Finance directly; it interprets the results already returned by the tools.

# %%
response = agent.analyze(user_question)
print(response.content)
# Out:
# # Comparison of AAPL, MSFT, and SPY Performance, Volatility, and Drawdowns Over the Last Year
#
# ## Executive Summary
# This report summarizes performance, volatility, and drawdown data for Apple (AAPL), Microsoft (MSFT), and the S&P 500 ETF (SPY) over a one-year period. The chart at the end provides visual comparisons.
#
# ## Factual Findings from the Tools
# - **AAPL**:
#     - Last Close: $312.06
#     - Cumulative Return (%) : +55.99%
#     - Annualized Volatility (%) : 22.08%
#     - Maximum Drawdown (%) : -13.8%
#
# - **MSFT**:
#     - Last Close: $450.24
#     - Cumulative Return (%) : -1.42%
#     - Annualized Volatility (%) : 24.56%
#     - Maximum Drawdown (%) : -33.91%
#
# - **SPY**:
#     - Last Close: $756.48
#     - Cumulative Return (%) : +29.82%
#     - Annualized Volatility (%) : 11.86%
#     - Maximum Drawdown (%) : -8.88%
#
# ## Risk and Drawdown Interpretation
#
# ### AAPL
# - **Performance**: Significant growth with a cumulative return of 55.99%. However, it had the highest volatility (22.08%) among the three.
# - **Drawdown**: The maximum drawdown was -13.8%, indicating that at its lowest point, investors could have lost up to 13.8% from their peak investment.
#
# ### MSFT
# - **Performance**: Despite starting at a high price, the stock showed negative returns (-1.42%). This is concerning and might indicate poor performance compared to AAPL.
# - **Drawdown**: The maximum drawdown of -33.91% means that if one held this stock during its peak, losses could have been severe.
#
# ### SPY
# - **Performance**: S&P 500 ETF showed moderate positive returns (29.82%), indicating a balanced performance.
# - **Drawdown**: The maximum drawdown of -8.88% is relatively low compared to other stocks, suggesting that while there were downturns, they did not significantly impact overall gains.
#
# ## Limitations
# - The analysis considers historical data and does not account for future events or market conditions which could affect performance.
# - There are no specific insights into factors influencing stock prices such as macroeconomic changes, technological advancements affecting the companies, or other externalities that may influence investor sentiment.
#
# ## Suggested Next Analyses
#
# 1. **Institutional vs Individual Performance**: Analyze how institutional investors compared to individual retail investors have performed with these stocks.
# 2. **Sector Analysis**: Investigate if any particular sectors within these companies contribute significantly more to their performance than others.
# 3. **Factor Analysis**: Examine which factors (e.g., economic indicators, company-specific news) might explain variations in stock returns.
#
# ---
#
# **Chart Path:** [D:\\Documentos\\Universidad Externado\\Seminario - Multiagentes\\agents\\financial_research_agent\\outputs\*aapl_msft_spy_1y_comparison.png]

# %%
response.tool_plan
# Out:
# {'tools': [{'name': 'compare_stocks',
#    'arguments': {'tickers': ['AAPL', 'MSFT', 'SPY'], 'period': '1y'}}]}

# %%
response.tool_results
# Out:
# {'step_1_compare_stocks': {'tickers': ['AAPL', 'MSFT', 'SPY'],
#   'period': '1y',
#   'metrics': [{'ticker': 'AAPL',
#     'last_close': 312.06,
#     'cumulative_return_pct': 55.99,
#     'annualized_volatility_pct': 22.08,
#     'max_drawdown_pct': -13.8},
#    {'ticker': 'MSFT',
#     'last_close': 450.24,
#     'cumulative_return_pct': -1.42,
#     'annualized_volatility_pct': 24.56,
#     'max_drawdown_pct': -33.91},
#    {'ticker': 'SPY',
#     'last_close': 756.48,
#     'cumulative_return_pct': 29.82,
#     'annualized_volatility_pct': 11.86,
#     'max_drawdown_pct': -8.88}],
#   'chart_path': 'D:\\Documentos\\Universidad Externado\\Seminario - Multiagentes\\agents\\financial_research_agent\\outputs\\aapl_msft_spy_1y_comparison.png',
#   'start_date': '2025-05-30',
#   'end_date': '2026-05-29'}}

# %% [markdown]
# ## Display generated chart
#
# If the plan included a charting tool, the PNG path is stored inside `tool_results`.

# %%
from IPython.display import Image, display

for result in response.tool_results.values():
    chart_path = result.get("chart_path") if isinstance(result, dict) else None
    if chart_path:
        display(Image(filename=chart_path))
