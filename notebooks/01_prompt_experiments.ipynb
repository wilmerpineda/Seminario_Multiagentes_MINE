# %% [markdown]
# # Laboratorio 01
# # Cómo programar agentes usando lenguaje natural
#
# ## Objetivo
#
# Comprender cómo pequeños cambios en un prompt modifican el comportamiento de un agente basado en modelos de lenguaje.

# %%
from pathlib import Path
import sys

CURRENT_DIR = Path.cwd()

if CURRENT_DIR.name == "notebooks":
    PROJECT_ROOT = CURRENT_DIR.parent
else:
    PROJECT_ROOT = CURRENT_DIR

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(PROJECT_ROOT)
# Out:
# d:\Documentos\Universidad Externado\Agentes - Ejemplo

# %%
from agents.experiment_analyst_agent.agent import ExperimentAnalystAgent

agent = ExperimentAnalystAgent(model_name='qwen2.5:3b')

# %% [markdown]
# ## Experimento 1 — Ambigüedad

# %%
response = agent.analyze('', 'Analyze this experiment.', "../data/data_activations.csv")
print(response.content)
# Out:
# ### Analysis of Experiment Data
#
# #### 1. Overview of Experiment Performance
#
# The experiment we are evaluating involves two different groups: "Journey" (Group A) and "MLD" (Group B). The total rate across all users is 0.243526, indicating that about 24.35% of users activate the desired feature or perform the intended action.
#
# #### 2. Performance Metrics
#
# ##### Group A: Journey
# - Users: 250,000
# - Activations: 63,330
# - Activation Rate: 0.253320 (or approximately 25.33%)
#
# ##### Group B: MLD
# - Users: 250,000
# - Activations: 58,433
# - Activation Rate: 0.233732 (or approximately 23.37%)
#
# #### 3. Segment Analysis
#
# To better understand the differences between users in "Journey" and "MLD," we look at the performance within different segments:
#
# ##### Organic Users
# For users from organic sources, the activation rates are:
# - MLD: 0.334378 (or approximately 33.44%)
# - Journey: 0.301949 (or approximately 30.2%)
#
# ##### Ecosistemic/Ecosistémico Users
# ...

# %% [markdown]
# ## Experimento 2 — Rol

# %%
response = agent.analyze('', 'Act as a senior experimentation analyst. Analyze this experiment.', "../data/data_activations.csv")
print(response.content)
# Out:
# ### Analysis of Experiment Results
#
# #### Summary of Key Findings:
#
# 1. **Total Activation Rate:**
#    The overall activation rate across all users in both experiments is 0.243526 or 24.35%.
#
# 2. **Experimento Users and Activations:**
#    - **Journey Experiment:**
#      - Total Users: 250,000
#      - Total Activations: 63,330
#      - Activation Rate: 0.253320 or 25.33%
#
#    - **MLD Experiment:**
#      - Total Users: 250,000
#      - Total Activations: 58,433
#      - Activation Rate: 0.233732 or 23.37%
#
# 3. **Segmental Analysis:**
#
#    The activation rates vary significantly across different user segments:
#
#    - **MLD Experiment:**
#      - Organic Users (Orgánico):
#        - Total Users: 64,472
#        - Total Activations: 21,558
#        - Activation Rate: 0.334378 or 33.44%
#
#      - Ecosistemic Users (Ecosistemic):
#        - Total Users: 5,617
#        - Total Activations: 1,088
#        - Activation Rate: 0.193698 or 19.37%
#
# ...

# %% [markdown]
# ## Experimento 3 — Contexto

# %%
context = '''We are running an A/B test.\nMLD Activation Rate: 23.37%\nJourney Activation Rate: 25.33%'''
response = agent.analyze(context, 'Explain possible reasons.', "../data/data_activations.csv")
print(response.content)
# Out:
# ### Explanation of Possible Reasons
#
# Based on the data provided, we can observe differences in activation rates between the two experimental treatments (Journey and MLD). Here are some insights and potential reasons:
#
# #### Fact 1: Activation Rates by Experiment
# - **MLD:** 23.37% activation rate.
# - **Journey:** 25.33% activation rate.
#
# #### Reasoning:
# The difference in activation rates between the two experiments could be attributed to various factors such as user behavior, campaign effectiveness, or demographic differences among users.
#
# 1. **User Preferences and Behavior:**
#    - Users engaging with the MLD (Multichannel Direct) may have different preferences than those using the Journey route.
#    - For example, users in Segmento "Orgánico" showed a very high activation rate of 33.44% under the MLD experiment, while users in Segmento "Journey Orgánico" had an activation rate as low as 29.74%.
#
# 2. **Segment Differences:**
# ...
